# %% [markdown]
# <a href="https://colab.research.google.com/github/Chenko-4/Pemrograman-Dasar/blob/main/Pertemuan_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Biodata saya

nama= "Chenko Razin Rabbani"
umur= "19"
asal= "Jawa Tengah"
hobi= "Dengerin Music"
jurusan= "RPE"
nim= "4232501052"
semester= 3
matakuliah='Pemrograman Dasar'
status_lulus= False


print (nama)
print (umur)
print (asal)
print (hobi)
print (jurusan)
print (nim)
print (matakuliah)
print (status_lulus)
# Out:
# Chenko Razin Rabbani
# 19
# Jawa Tengah
# Dengerin Music
# RPE
# 4232501052
# Pemrograman Dasar
# False
